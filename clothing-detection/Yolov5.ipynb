# %% [markdown]
# # YOLOv5

# %%
base_directory = "/home/j-j9s006"
dataset_directory = "/home/j-j9s006/datasets/yolo/v1-aug"

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "9" 

import torch
print(torch.cuda.is_available())

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# True
# cuda

# %% [markdown]
# ### Installing the YOLOv5 Environment

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies

# %%
# %pwd
# Out:
# '/home/j-j9s006/clothing-detection/yolov5/v1'

# %% [markdown]
# ### 학습

# %%
import torch
from IPython.display import Image  # for displaying images

print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 2.0.1+cu117 _CudaDeviceProperties(name='Tesla V100-PCIE-32GB', major=7, minor=0, total_memory=32510MB, multi_processor_count=80)

# %%
# !cat {dataset_directory}/data.yaml
# Out:
# train: /home/j-j9s006/datasets/yolo/v1-aug/train.txt
# val: /home/j-j9s006/datasets/yolo/v1-aug/valid/images
# test: /home/j-j9s006/datasets/yolo/v1-aug/test.txt
#
# nc: 1
# names: ['clothings']
#
# roboflow:
#   workspace: dadada
#   project: clothes-detection-tdoru
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/dadada/clothes-detection-tdoru/dataset/2

# %%
from glob import glob #이미지를 한번에 긁어모으기 위한 glob 모듈

img_list = glob(f'{dataset_directory}/train/images/*.jpg') # 트레인 이미지 경로
val_img_list = glob(f'{dataset_directory}/test/images/*.jpg') # 테스트 이미지 경로

# %%
with open(f'{dataset_directory}/train.txt', 'w') as f:
    f.write('\n'.join(img_list) + '\n')

    
with open(f'{dataset_directory}/test.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
# print(len(val_img_list))

# %% [markdown]
# ### 모델 학습

# %%
model_weight = "yolov5x"
image_size = 240

# %%
# !python train.py --img 240 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5l.pt --name result_jetbot --cfg ./models/yolov5l.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 480 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5s.pt --name result_jetbot --cfg ./models/yolov5s.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 480 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5m.pt --name result_jetbot --cfg ./models/yolov5m.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 480 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5l.pt --name result_jetbot --cfg ./models/yolov5l.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 480 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5x.pt --name result_jetbot --cfg ./models/yolov5x.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5s.pt --name result_jetbot --cfg ./models/yolov5s.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5m.pt --name result_jetbot --cfg ./models/yolov5m.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5l.pt --name result_jetbot --cfg ./models/yolov5l.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data {dataset_directory}/data.yaml --weights yolov5x.pt --name result_jetbot --cfg ./models/yolov5x.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %% [markdown]
# ### 객체 탐지

# %%
# !python detect.py --weights runs/train/result_jetbot5/weights/best.pt --img 640 --conf 0.25 --source {dataset_directory}/test/images/MRE2000000122_jpg.rf.ff180822edd9716abf92d0c74fd2d1f4.jpg
# Out:
# detect: weights=['runs/train/result_jetbot5/weights/best.pt'], source=/home/j-j9s006/datasets/yolov5/test/images/MRE2000000122_jpg.rf.ff180822edd9716abf92d0c74fd2d1f4.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.9.7 torch-2.0.1+cu117 CUDA:0 (Tesla V100-PCIE-32GB, 32511MiB)
#
# Fusing layers...
# YOLOv5x summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# image 1/1 /home/j-j9s006/datasets/yolov5/test/images/MRE2000000122_jpg.rf.ff180822edd9716abf92d0c74fd2d1f4.jpg: 640x640 1 clothings, 20.2ms
# ...
